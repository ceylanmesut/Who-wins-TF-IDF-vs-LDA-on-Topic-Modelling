# %% [markdown]
# # Exploratory Data Analysis
#
# ### Importing relevant libraries

# %%
import pandas as pd 
import matplotlib.pyplot as plt
from collections import Counter
import re
import nltk
from nltk.stem.porter import PorterStemmer
from tqdm import tqdm
from adjustText import adjust_text
# %matplotlib inline
plt.style.use('seaborn')

# %%
data = pd.read_csv("data\\co_data.csv")
data.head()
# Out:
#                  name                                        description  \
# 0  Pandora Car Rental  Welcome to Pandora Car Rental, Car Hire and Ai...
# 1        SurplusMatch  SurplusMatch is an online marketplace for cont...
# 2       Gimenez Ganga  Giménez Ganga is a company that has been provi...
# 3                SMC3  Freight shippers, motor carriers, logistics se...
# 4        Much Asphalt  Much Asphalt is southern Africa’s commercial s...
#
#           country founding_date  relevancy
# 0  United Kingdom    05/04/2011          0
# 1  United Kingdom    01/01/2008          2
# 2     Switzerland    01/01/1959          0
# 3   United States    01/01/1935          0
# 4    South Africa    01/01/1965          0

# %%
data.tail()
# Out:
#                            name  \
# 1995  James Fisher and Sons plc
# 1996                        AEG
# 1997                      mov.e
# 1998                   ambiHome
# 1999            Construirbarato
#
#                                             description         country  \
# 1995  James Fisher and Sons plc is a leading provide...  United Kingdom
# 1996  The AEG brand offers a full range of products ...   United States
# 1997  Digital platform that enables sharing of elect...        Portugal
# 1998  ambiHome is a fresh company based in Aachen/Ge...         Germany
# 1999  Construirbarato.com.br is an online platform t...          Brazil
#
#      founding_date  relevancy
# 1995    01/01/1847          0
# 1996    01/01/1887          1
# 1997    01/01/2018          2
# 1998    01/01/2009          0
# 1999    01/01/2009          1

# %% [markdown]
# The datasets consists of four columns, containing company name, description, country, founding date and relevancy label.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           2000 non-null   object
#  1   description    2000 non-null   object
#  2   country        2000 non-null   object
#  3   founding_date  2000 non-null   object
#  4   relevancy      2000 non-null   int64
# dtypes: int64(1), object(4)
# memory usage: 78.2+ KB

# %% [markdown]
# ### Couple of examples from dataset prior to preprocessing

# %%
data["description"][3]
# Out:
# 'Freight shippers, motor carriers, logistics service providers and other supply chain professionals look to SMC³ for the technology, industry data, educational services and general know-how to achieve greater success in the transportation marketplace. The company is best known for its CzarLite base rates, which are used as a price benchmark in transportation agreements. Additionally SMC³ produces a range of enabling technologies that give shippers and carriers complete visibility into their transportation spend. Each January and June, SMC³ hosts a comprehensive supply chain conference that gives industry professionals an inside look into cost-saving trends and best business practices as well as timely economic and legislative updates.'

# %%
data["description"][1999]
# Out:
# 'Construirbarato.com.br is an online platform that allows its users to search and compare prices of products and services related to construction. It was launched in 2009 and is based in Rio de Janeiro, Brazil.'

# %%
data["description"][0]
# Out:
# 'Welcome to Pandora Car Rental, Car Hire and Airport Transfers based in Dalaman Turkey. \xa0We have a wide range of cars to suit all budgets and can deliver your car for free anytime day or night within the Dalaman locality.\r\n\r\n\r\nReasons to Book Car from Pandora Car Rental:\r\n\r\nUnlimited Milage\r\nVAT\r\nAll Local Taxes\r\nAirport Service Charge where applicable\r\n24 hours Road Service\r\nThird Party Insurance with NO Excess\r\nTheft Insurance with NO Excess\r\nFire Insurance with NO Excess\r\nFDW Insurance with NO Excess\r\nCDW Collision Damage Waiver with NO Excess\r\nTWH Tyre Windscreen Headlight Insurance with NO Excess\r\n3 Additional Drivers\r\nChild/Baby Seat (must be ordered)\r\nNo Hidden Extras\r\n\r\n\r\nAddress:\r\nHadrian Flats Number 4\xa0\r\nWellington Telford \r\nPin Code: TF11RQ\r\nTel:\xa0\xa0+ 44 776 558 66 77\xa0\r\nWebsite: http://www.dalamancarrental.com'

# %% [markdown]
# ### Preprocessing the dataset

# %%
# downloading English stop words
nltk.download('stopwords')
stopwords = nltk.corpus.stopwords.words('english')

for ind, row in data.iterrows():
    text = row["description"]
    #websites, email and any punctuation cleaning
    text = re.sub("((\S+)?(http(s)?)(\S+))|((\S+)?(www)(\S+))|((\S+)?(\@)(\S+)?)", " ", text)
    text = re.sub("[^a-zA-Z ]", "", text)
    text = text.lower() # lower case the text
    text = nltk.word_tokenize(text)
    #removing stopwords
    text = [word for word in text if word not in stopwords]
    
    data.at[ind, "description"] = " ".join(text)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
data["description"][0]
# Out:
# 'welcome pandora car rental car hire airport transfers based dalaman turkey wide range cars suit budgets deliver car free anytime day night within dalaman localityreasons book car pandora car rentalunlimited milagevatall local taxesairport service charge applicable hours road servicethird party insurance excesstheft insurance excessfire insurance excessfdw insurance excesscdw collision damage waiver excesstwh tyre windscreen headlight insurance excess additional driverschildbaby seat must orderedno hidden extrasaddresshadrian flats number wellington telford pin code tfrqtel website'

# %%
data["description"][1999]
# Out:
# 'construirbaratocombr online platform allows users search compare prices products services related construction launched based rio de janeiro brazil'

# %% [markdown]
# Creating additional columns such as founding year and word count of each company description

# %%
# creating founding year
data["founding_year"] = pd.DatetimeIndex(data["founding_date"]).year

# extracting word count
data["word_count"] = data.description.apply(lambda x: len(x.split(" ")))

# %% [markdown]
# ### Founding date distribution

# %%
plt.figure(figsize=(14,8))

year_freq = data.groupby(["founding_year"])["name"].count().reset_index(name="frequencies")
plt.bar(year_freq["founding_year"], year_freq["frequencies"])
plt.xlim(1819, 2025)

plt.xlabel("Foundation Years")
plt.ylabel("Frequencies")
plt.title("Founding Dates")
# Out:
# Text(0.5, 1.0, 'Founding Dates')

# %% [markdown]
# We observe that most of the companies included in our dataset founded after 1975.

# %% [markdown]
# ### Word count distribution

# %%
plt.figure(figsize=(14,8))
country_freq = data.groupby(["word_count"])["name"].count().reset_index(name="frequencies")
plt.bar(country_freq["word_count"], country_freq["frequencies"])
plt.xlabel("Word Count")
plt.ylabel("Frequencies")
plt.title("Word Counts")
plt.xlim(0, 200)
# Out:
# (0.0, 200.0)

# %% [markdown]
# Let's have a look at top words used in the company description w.r.t founding year

# %%
# creating separate lists for the top 3 used words in the company descriptions
years = data.founding_year.drop_duplicates()
sorted_years = sorted(years)

top_1 = []
top_2 = []
top_3 = []

word_freqs = []
for year in tqdm(sorted_years):
    
    F = nltk.FreqDist([i for i in ' '.join(data.query(f'founding_year=={year}').description).split() if i not in stopwords])
    word_freqs.append(F)
        
    result = [i for i in F.most_common(3)]  
    
    top_1.append(result[0])
    top_2.append(result[1])
    top_3.append(result[2])
# Out:
# 100%|██████████| 137/137 [00:02<00:00, 68.16it/s]

# %%
word_freqs
# Out:
# [FreqDist({'mail': 3, 'business': 3, 'company': 3, 'singapore': 2, 'logistics': 2, 'retail': 2, 'main': 2, 'awards': 2, 'postal': 2, 'service': 2, ...}),
#  FreqDist({'equipment': 5, 'stedman': 3, 'size': 3, 'reduction': 3, 'parts': 3, 'machine': 2, 'company': 2, 'consistent': 2, 'product': 2, 'industry': 2, ...}),
#  FreqDist({'gasag': 2, 'berliner': 2, 'gaswerke': 2, 'services': 2, 'gas': 2, 'ag': 1, 'provides': 1, 'utility': 1, 'company': 1, 'offers': 1, ...}),
#  FreqDist({'ecom': 1, 'agroindustrial': 1, 'commodity': 1, 'merchant': 1, 'sustainable': 1, 'supply': 1, 'chain': 1, 'management': 1, 'company': 1}),
#  FreqDist({'readymixed': 2, 'concrete': 2, 'vicat': 1, 'produces': 1, 'sells': 1, 'cement': 1, 'aggregate': 1, 'products': 1, 'worldwide': 1, 'offers': 1, ...}),
#  FreqDist({'construction': 7, 'natie': 5, 'katoen': 3, 'logistics': 3, 'services': 3, 'industries': 2, 'port': 2, 'service': 2, 'management': 2, 'engineering': 2, ...}),
#  FreqDist({'right': 2, 'us': 2, 'door': 2, 'strategic': 2, 'wijnne': 1, 'barends': 1, 'always': 1, 'offers': 1, 'vessel': 1, 'time': 1, ...}),
#  FreqDist({'elevion': 2, 'building': 2, 'technical': 2, 'service': 2, 'projects': 2, 'group': 2, 'companies': 2, 'gmbh': 1, 'facilities': 1, 'providermodern': 1, ...}),
#  FreqDist({'rics': 1, 'worlds': 1, 'leading': 1, 'professional': 1, 'body': 1, 'qualifications': 1, 'standards': 1, 'land': 1, 'property': 1, 'construction': 1}),
#  FreqDist({'group': 4, 'bam': 3, 'royal': 2, 'construction': 2, 'markets': 2, 'building': 1, 'public': 1, 'works': 1, 'nv': 1, 'company': 1, ...}),
#  FreqDist({'construction': 3, 'offshore': 2, 'bilfinger': 1, 'marine': 1, 'systems': 1, 'gmbh': 1, 'german': 1, 'company': 1, 'active': 1, 'engineering': 1, ...}),
#  FreqDist({'village': 1, 'downers': 1, 'grove': 1, 'il': 1, 'suburb': 1, 'convenient': 1, 'rail': 1, 'road': 1, 'access': 1, 'chicago': 1}),
#  FreqDist({'duct': 5, 'sheet': 3, 'air': 3, 'commercial': 2, 'hvac': 2, 'construction': 2, 'steel': 2, 'metal': 2, 'centers': 2, 'quality': 2, ...}),
#  FreqDist({'customers': 4, 'industry': 3, 'equipment': 3, 'commercial': 2, 'construction': 1, 'heating': 1, 'ventilating': 1, 'air': 1, 'conditioning': 1, 'roofing': 1, ...}),
#  FreqDist({'railway': 4, 'works': 3, 'tunnels': 3, 'water': 2, 'projects': 2, 'underground': 2, 'shafts': 2, 'societa': 1, 'italiana': 1, 'per': 1, ...}),
#  FreqDist({'mosa': 4, 'tiles': 3, 'manufacturer': 2, 'ceramic': 2, 'market': 2, 'royal': 2, 'koninklijke': 1, 'tilesroyal': 1, 'dutch': 1, 'factories': 1, ...}),
#  FreqDist({'nuclear': 3, 'plant': 2, 'westinghouse': 1, 'electric': 1, 'company': 1, 'supplier': 1, 'safe': 1, 'innovative': 1, 'technology': 1, 'provide': 1, ...}),
#  FreqDist({'brand': 3, 'electric': 2, 'years': 2, 'power': 2, 'aeg': 1, 'offers': 1, 'full': 1, 'range': 1, 'products': 1, 'continue': 1, ...}),
#  FreqDist({'aalborg': 8, 'cement': 7, 'portland': 5, 'production': 2, 'market': 2, 'customers': 2, 'improving': 2, 'denmarks': 1, 'producer': 1, 'factory': 1, ...}),
#  FreqDist({'pooling': 1, 'partners': 1, 'works': 1, 'together': 1, 'range': 1, 'customers': 1, 'users': 1, 'across': 1, 'europes': 1, 'supply': 1, ...}),
#  FreqDist({'mccourt': 3, 'projects': 3, 'construction': 2, 'utility': 2, 'small': 2, 'comprehensive': 1, 'general': 1, 'contractor': 1, 'strengths': 1, 'infrastructure': 1, ...}),
#  FreqDist({'cast': 2, 'montupet': 1, 'designs': 1, 'manufactures': 1, 'aluminium': 1, 'components': 1, 'automotive': 1, 'industry': 1, 'worldwide': 1, 'company': 1, ...}),
#  FreqDist({'hertel': 5, 'clients': 3, 'service': 2, 'maintenance': 2, 'services': 2, 'around': 2, 'company': 2, 'established': 1, 'global': 1, 'multidisciplinary': 1, ...}),
#  FreqDist({'gilman': 2, 'products': 2, 'company': 2, 'brothers': 1, 'co': 1, 'one': 1, 'north': 1, 'americas': 1, 'premier': 1, 'manufacturers': 1, ...}),
#  FreqDist({'tishman': 10, 'real': 6, 'estate': 6, 'management': 6, 'construction': 4, 'billion': 3, 'assets': 3, 'chairman': 3, 'staff': 2, 'years': 2, ...}),
#  FreqDist({'dematic': 3, 'global': 2, 'range': 2, 'materials': 2, 'handling': 2, 'solutions': 2, 'provide': 2, 'world': 2, 'class': 2, 'solution': 2, ...}),
#  FreqDist({'steel': 6, 'company': 4, 'products': 2, 'founded': 2, 'headquartered': 2, 'gerdau': 2, 'profiles': 2, 'also': 2, 'mcmastercarr': 1, 'develops': 1, ...}),
#  FreqDist({'nix': 3, 'companies': 2, 'metal': 2, 'business': 2, 'fabricator': 1, 'company': 1, 'specializes': 1, 'works': 1, 'job': 1, 'shop': 1, ...}),
#  FreqDist({'warehousing': 2, 'logistics': 2, 'solutions': 2, 'americold': 1, 'global': 1, 'leader': 1, 'temperature': 1, 'controlled': 1, 'food': 1, 'industry': 1, ...}),
#  FreqDist({'construction': 4, 'engineering': 3, 'technical': 2, 'services': 2, 'management': 2, 'general': 2, 'aci': 1, 'educational': 1, 'institution': 1, 'teaches': 1, ...}),
#  FreqDist({'company': 7, 'transport': 7, 'services': 7, 'group': 7, 'fs': 6, 'italiane': 6, 'mercitalia': 6, 'railway': 5, 'companies': 4, 'rail': 4, ...}),
#  FreqDist({'company': 12, 'alabama': 5, 'power': 3, 'sells': 3, 'electricity': 3, 'grain': 3, 'obryan': 3, 'began': 3, 'processing': 3, 'generation': 3, ...}),
#  FreqDist({'motor': 3, 'operates': 2, 'retail': 2, 'aftersales': 2, 'company': 2, 'distribution': 2, 'parts': 2, 'franchised': 2, 'office': 2, 'j': 2, ...}),
#  FreqDist({'infrastructure': 7, 'international': 3, 'engineering': 2, 'client': 2, 'large': 2, 'small': 2, 'deliver': 2, 'innovation': 2, 'together': 2, 'finance': 2, ...}),
#  FreqDist({'construction': 2, 'journey': 1, 'group': 1, 'management': 1, 'general': 1, 'contracting': 1, 'firm': 1, 'employees': 1, 'four': 1, 'units': 1, ...}),
#  FreqDist({'snclavalin': 3, 'infrastructure': 2, 'provide': 2, 'services': 2, 'clients': 2, 'complete': 2, 'founded': 1, 'one': 1, 'leading': 1, 'engineering': 1, ...}),
#  FreqDist({'cinx': 3, 'construction': 2, 'platform': 2, 'todays': 2, 'information': 1, 'network': 1, 'exchange': 1, 'cloud': 1, 'helps': 1, 'easily': 1, ...}),
#  FreqDist({'bpb': 1, 'plc': 1, 'manufactures': 1, 'supplies': 1, 'plasterboard': 1, 'gypsum': 1, 'plasters': 1, 'well': 1, 'insulation': 1, 'ceiling': 1, ...}),
#  FreqDist({'want': 2, 'bob': 1, 'smith': 1, 'bmw': 1, 'helped': 1, 'many': 1, 'people': 1, 'get': 1, 'car': 1, 'near': 1, ...}),
#  FreqDist({'products': 4, 'validation': 3, 'g': 2, 'w': 2, 'laboratories': 2, 'inc': 2, 'offers': 2, 'creams': 2, 'suppositories': 2, 'topical': 2, ...}),
#  FreqDist({'thapar': 7, 'coal': 7, 'business': 7, 'company': 5, 'including': 4, 'group': 3, 'karam': 3, 'chand': 3, 'inder': 3, 'mohan': 3, ...}),
#  FreqDist({'leeds': 1, 'welding': 1, 'co': 1, 'ltd': 1, 'founded': 1, 'companys': 1, 'line': 1, 'business': 1, 'includes': 1, 'providing': 1, ...}),
#  FreqDist({'mrc': 3, 'products': 3, 'services': 3, 'company': 3, 'pipe': 2, 'fitting': 2, 'energy': 2, 'market': 2, 'service': 2, 'employees': 2, ...}),
#  FreqDist({'warehousing': 3, 'believe': 2, 'great': 2, 'largest': 2, 'infrastructure': 2, 'projects': 2, 'construction': 2, 'transportation': 2, 'work': 2, 'service': 2, ...}),
#  FreqDist({'berlin': 7, 'company': 6, 'trade': 5, 'construction': 4, 'fair': 3, 'event': 3, 'well': 3, 'business': 3, 'germany': 3, 'baywa': 3, ...}),
#  FreqDist({'solutions': 4, 'transport': 4, 'wire': 3, 'rope': 3, 'bridon': 2, 'international': 2, 'demanding': 2, 'worldwide': 2, 'offices': 2, 'provide': 2, ...}),
#  FreqDist({'construction': 6, 'group': 4, 'industry': 4, 'ko': 3, 'revenues': 2, 'employees': 2, 'leading': 2, 'energy': 2, 'api': 2, 'inc': 2, ...}),
#  FreqDist({'construction': 7, 'management': 2, 'services': 2, 'electrical': 2, 'kenny': 1, 'provides': 1, 'general': 1, 'contracting': 1, 'united': 1, 'states': 1, ...}),
#  FreqDist({'construction': 2, 'electrical': 2, 'leader': 2, 'rail': 2, 'mass': 1, 'electric': 1, 'co': 1, 'mec': 1, 'one': 1, 'nations': 1, ...}),
#  FreqDist({'construction': 5, 'business': 4, 'ohio': 4, 'insulation': 3, 'sand': 3, 'gravel': 3, 'asphalt': 3, 'leading': 2, 'branches': 2, 'market': 2, ...}),
#  FreqDist({'roofing': 3, 'thomas': 1, 'smith': 1, 'centres': 1, 'contractor': 1, 'sells': 1, 'building': 1, 'materials': 1}),
#  FreqDist({'binladin': 3, 'history': 1, 'begins': 1, 'kingdoms': 1, 'early': 1, 'years': 1, 'reign': 1, 'king': 1, 'abdul': 1, 'aziz': 1, ...}),
#  FreqDist({'construction': 4, 'port': 4, 'company': 3, 'solutions': 3, 'logistics': 3, 'provider': 3, 'care': 2, 'industrial': 2, 'people': 2, 'throughout': 2, ...}),
#  FreqDist({'downer': 4, 'new': 3, 'australia': 2, 'exchange': 2, 'zealand': 2, 'limited': 2, 'also': 2, 'group': 2, 'designs': 1, 'builds': 1, ...}),
#  FreqDist({'glass': 7, 'phoenicia': 3, 'customers': 3, 'production': 3, 'lines': 3, 'developing': 2, 'year': 2, 'experience': 2, 'float': 2, 'designed': 2, ...}),
#  FreqDist({'smc': 3, 'transportation': 3, 'shippers': 2, 'carriers': 2, 'supply': 2, 'chain': 2, 'professionals': 2, 'look': 2, 'industry': 2, 'best': 2, ...}),
#  FreqDist({'design': 4, 'construction': 3, 'company': 3, 'williams': 3, 'inc': 3, 'engineering': 3, 'service': 3, 'services': 3, 'industrial': 2, 'fred': 2, ...}),
#  FreqDist({'zep': 4, 'market': 3, 'sales': 2, 'maintenance': 2, 'brands': 2, 'construction': 2, 'inc': 1, 'fiscal': 1, 'year': 1, 'net': 1, ...}),
#  FreqDist({'construction': 6, 'linbeck': 6, 'building': 4, 'equipment': 3, 'service': 3, 'systems': 3, 'engineering': 2, 'sales': 2, 'large': 2, 'new': 2, ...}),
#  FreqDist({'services': 7, 'construction': 5, 'products': 4, 'company': 3, 'management': 3, 'kansas': 3, 'hamm': 3, 'waste': 3, 'projects': 3, 'maintenance': 3, ...}),
#  FreqDist({'anson': 2, 'company': 2, 'contractors': 2, 'industries': 1, 'parent': 1, 'anning': 1, 'johnson': 1, 'restec': 1, 'inc': 1, 'companies': 1, ...}),
#  FreqDist({'velux': 4, 'construction': 3, 'villum': 3, 'kann': 3, 'rasmussen': 3, 'snam': 2, 'gas': 2, 'first': 2, 'roof': 2, 'window': 2, ...}),
#  FreqDist({'rapido': 1, 'cometa': 1, 'logistica': 1, 'e': 1, 'transportes': 1, 'sa': 1, 'brazilbased': 1, 'transportation': 1, 'logistics': 1, 'services': 1, ...}),
#  FreqDist({'logistics': 5, 'management': 4, 'valuables': 4, 'locations': 3, 'pallets': 3, 'company': 3, 'group': 3, 'storage': 3, 'jm': 2, 'leading': 2, ...}),
#  FreqDist({'express': 4, 'services': 4, 'international': 4, 'air': 4, 'delivery': 3, 'parcel': 3, 'transportation': 2, 'largest': 2, 'countries': 2, 'strong': 2, ...}),
#  FreqDist({'systems': 8, 'services': 7, 'power': 4, 'shipping': 3, 'electrical': 3, 'business': 3, 'provides': 3, 'commercial': 3, 'industrial': 3, 'customers': 3, ...}),
#  FreqDist({'services': 5, 'moving': 4, 'storage': 4, 'era': 4, 'group': 4, 'corovan': 3, 'commercial': 3, 'company': 3, 'us': 3, 'helicopter': 3, ...}),
#  FreqDist({'sumitomo': 2, 'inc': 2, 'mechanical': 2, 'realty': 1, 'development': 1, 'active': 1, 'subsidiary': 1, 'corporation': 1, 'handles': 1, 'real': 1, ...}),
#  FreqDist({'engineering': 4, 'services': 3, 'resources': 3, 'testing': 3, 'inc': 2, 'environmental': 2, 'greenhorne': 1, 'omara': 1, 'provides': 1, 'consulting': 1, ...}),
#  FreqDist({'provider': 2, 'christian': 1, 'testing': 1, 'laboratories': 1, 'ctl': 1, 'every': 1, 'type': 1, 'geotechnical': 1, 'service': 1, 'required': 1, ...}),
#  FreqDist({'industrial': 5, 'services': 4, 'company': 4, 'products': 4, 'napec': 3, 'construction': 3, 'maintenance': 3, 'lawson': 3, 'repair': 3, 'provides': 2, ...}),
#  FreqDist({'products': 3, 'parts': 2, 'automotive': 2, 'logistics': 2, 'offers': 2, 'extrusion': 2, 'ferrills': 1, 'auto': 1, 'operates': 1, 'recycling': 1, ...}),
#  FreqDist({'aruba': 3, 'aircraft': 3, 'registration': 3, 'services': 3, 'first': 2, 'offering': 2, 'management': 2, 'service': 2, 'manufacture': 2, 'tetra': 2, ...}),
#  FreqDist({'equipment': 6, 'hugg': 3, 'hall': 3, 'eye': 3, 'company': 2, 'one': 2, 'service': 2, 'industrial': 2, 'strong': 2, 'market': 2, ...}),
#  FreqDist({'business': 4, 'clients': 3, 'solutions': 3, 'one': 2, 'global': 2, 'dedicated': 2, 'processes': 2, 'costs': 2, 'ctsiglobals': 1, 'empowered': 1, ...}),
#  FreqDist({'ritchie': 7, 'bros': 7, 'services': 6, 'service': 6, 'equipment': 6, 'industry': 6, 'company': 5, 'electric': 5, 'hoist': 5, 'flow': 5, ...}),
#  FreqDist({'products': 4, 'mechanical': 3, 'company': 2, 'solutions': 2, 'bg': 2, 'contractor': 2, 'contractors': 2, 'highly': 2, 'markets': 2, 'buildings': 2, ...}),
#  FreqDist({'businesses': 7, 'services': 6, 'opportunities': 4, 'also': 3, 'development': 3, 'investment': 3, 'network': 3, 'groups': 3, 'scale': 3, 'improve': 3, ...}),
#  FreqDist({'solutions': 4, 'belgium': 3, 'logistics': 3, 'well': 3, 'consumers': 3, 'campaigns': 3, 'products': 3, 'services': 3, 'myshopi': 2, 'omnichannel': 2, ...}),
#  FreqDist({'concrete': 8, 'equipment': 7, 'based': 5, 'systems': 5, 'injection': 4, 'spraying': 3, 'resins': 3, 'cannon': 3, 'military': 2, 'vehicles': 2, ...}),
#  FreqDist({'logistics': 4, 'handling': 3, 'management': 3, 'truck': 3, 'leasing': 3, 'provide': 2, 'reliable': 2, 'solutions': 2, 'conveyors': 2, 'equipment': 2, ...}),
#  FreqDist({'company': 7, 'products': 7, 'services': 7, 'calcium': 5, 'engineering': 4, 'concrete': 4, 'stone': 3, 'chloride': 3, 'also': 3, 'product': 3, ...}),
#  FreqDist({'construction': 5, 'asphalt': 4, 'equipment': 4, 'customers': 4, 'management': 4, 'range': 3, 'products': 3, 'herc': 3, 'rentals': 3, 'rental': 3, ...}),
#  FreqDist({'tekla': 7, 'international': 4, 'construction': 2, 'infrastructure': 2, 'bim': 2, 'field': 2, 'structural': 2, 'waberers': 2, 'leader': 2, 'services': 2, ...}),
#  FreqDist({'living': 6, 'toll': 5, 'brothers': 5, 'communities': 5, 'luxury': 5, 'toyota': 5, 'active': 3, 'urban': 3, 'new': 3, 'service': 3, ...}),
#  FreqDist({'company': 10, 'services': 7, 'access': 5, 'equipment': 5, 'provides': 5, 'steel': 5, 'sales': 5, 'customers': 4, 'engineering': 4, 'products': 4, ...}),
#  FreqDist({'provides': 4, 'technical': 2, 'services': 2, 'ats': 2, 'specification': 2, 'designers': 2, 'construction': 2, 'intergraph': 2, 'enterprises': 2, 'data': 2, ...}),
#  FreqDist({'services': 6, 'construction': 5, 'development': 4, 'systems': 4, 'products': 4, 'engineering': 3, 'company': 3, 'also': 3, 'union': 3, 'businesses': 3, ...}),
#  FreqDist({'services': 9, 'business': 6, 'company': 5, 'maintenance': 4, 'commercial': 4, 'facilities': 4, 'support': 4, 'pt': 4, 'management': 4, 'indonesia': 4, ...}),
#  FreqDist({'company': 12, 'products': 10, 'logistics': 8, 'services': 8, 'construction': 8, 'coffee': 8, 'service': 7, 'markers': 7, 'provides': 5, 'offers': 5, ...}),
#  FreqDist({'services': 13, 'engineering': 11, 'provides': 7, 'company': 6, 'industry': 5, 'business': 4, 'quality': 4, 'customers': 4, 'punch': 3, 'consulting': 3, ...}),
#  FreqDist({'manpower': 18, 'services': 15, 'marine': 14, 'company': 12, 'world': 10, 'group': 9, 'years': 9, 'clients': 9, 'star': 8, 'holding': 8, ...}),
#  FreqDist({'adam': 6, 'hall': 6, 'company': 5, 'event': 4, 'construction': 4, 'manufacturer': 3, 'group': 3, 'technology': 3, 'new': 3, 'service': 3, ...}),
#  FreqDist({'services': 13, 'construction': 7, 'company': 6, 'dnv': 5, 'offshore': 5, 'provides': 5, 'group': 5, 'estimating': 4, 'including': 4, 'systems': 4, ...}),
#  FreqDist({'company': 8, 'freight': 7, 'tim': 4, 'insurance': 4, 'painting': 3, 'inc': 3, 'residential': 3, 'since': 3, 'glassworks': 3, 'one': 3, ...}),
#  FreqDist({'company': 13, 'construction': 10, 'management': 9, 'industrial': 7, 'services': 7, 'supply': 7, 'solutions': 6, 'products': 5, 'service': 5, 'wind': 5, ...}),
#  FreqDist({'products': 6, 'company': 4, 'provides': 4, 'service': 4, 'system': 4, 'insulation': 4, 'helps': 4, 'finance': 4, 'asphalt': 3, 'commercial': 3, ...}),
#  FreqDist({'company': 11, 'supply': 10, 'solutions': 10, 'business': 7, 'home': 7, 'cimc': 7, 'management': 6, 'products': 6, 'group': 6, 'insurance': 6, ...}),
#  FreqDist({'company': 7, 'services': 6, 'inc': 5, 'service': 5, 'include': 5, 'truck': 5, 'products': 5, 'chief': 5, 'fire': 4, 'design': 4, ...}),
#  FreqDist({'bim': 14, 'services': 13, 'products': 9, 'containers': 9, 'steel': 8, 'management': 8, 'design': 8, 'container': 8, 'provides': 7, 'shipping': 7, ...}),
#  FreqDist({'construction': 10, 'remodeling': 9, 'company': 8, 'logistics': 8, 'services': 7, 'solutions': 6, 'home': 6, 'bathroom': 6, 'years': 5, 'work': 5, ...}),
#  FreqDist({'equipment': 17, 'software': 15, 'services': 10, 'oil': 10, 'management': 9, 'provides': 8, 'design': 7, 'solutions': 7, 'construction': 6, 'company': 6, ...}),
#  FreqDist({'services': 14, 'provides': 12, 'design': 11, 'offers': 7, 'company': 7, 'transportation': 7, 'also': 7, 'construction': 6, 'systems': 6, 'logistics': 6, ...}),
#  FreqDist({'construction': 15, 'services': 13, 'transportation': 11, 'products': 10, 'solutions': 9, 'management': 8, 'company': 7, 'design': 7, 'provides': 7, 'engineering': 7, ...}),
#  FreqDist({'company': 14, 'inc': 13, 'services': 12, 'thermo': 10, 'us': 9, 'commercial': 8, 'business': 7, 'management': 7, 'pool': 7, 'master': 7, ...}),
#  FreqDist({'services': 16, 'construction': 13, 'systems': 10, 'products': 9, 'company': 8, 'home': 7, 'design': 7, 'management': 7, 'group': 7, 'infrastructure': 7, ...}),
#  FreqDist({'services': 16, 'construction': 11, 'equipment': 10, 'solutions': 9, 'quality': 9, 'provides': 8, 'industry': 8, 'customers': 8, 'service': 8, 'us': 7, ...}),
#  FreqDist({'services': 17, 'construction': 14, 'gharonda': 12, 'provides': 11, 'management': 11, 'service': 9, 'company': 9, 'engineering': 7, 'solutions': 7, 'software': 6, ...}),
#  FreqDist({'services': 11, 'company': 8, 'logistics': 7, 'construction': 7, 'maintenance': 6, 'water': 6, 'companies': 5, 'solutions': 5, 'right': 5, 'industrial': 5, ...}),
#  FreqDist({'et': 25, 'de': 25, 'la': 12, 'les': 11, 'company': 10, 'direct': 9, 'solutions': 8, 'logistics': 8, 'assurance': 8, 'un': 8, ...}),
#  FreqDist({'services': 17, 'logistics': 13, 'management': 10, 'engineering': 10, 'systems': 9, 'solutions': 8, 'construction': 7, 'company': 7, 'equipment': 7, 'home': 6, ...}),
#  FreqDist({'company': 13, 'services': 10, 'solutions': 9, 'construction': 9, 'inc': 9, 'waste': 8, 'products': 8, 'management': 8, 'topcon': 7, 'positioning': 7, ...}),
#  FreqDist({'management': 19, 'services': 15, 'provides': 11, 'insurance': 9, 'construction': 8, 'logistics': 8, 'solutions': 8, 'business': 7, 'supply': 7, 'trailers': 7, ...}),
#  FreqDist({'construction': 15, 'services': 12, 'companies': 8, 'industry': 7, 'abcs': 6, 'provides': 6, 'solutions': 6, 'service': 5, 'software': 5, 'company': 5, ...}),
#  FreqDist({'service': 19, 'services': 18, 'company': 15, 'management': 13, 'logistics': 12, 'construction': 12, 'products': 12, 'solutions': 11, 'customer': 10, 'provides': 10, ...}),
#  FreqDist({'company': 15, 'services': 15, 'technology': 14, 'provides': 13, 'development': 12, 'construction': 12, 'management': 11, 'solutions': 11, 'service': 11, 'products': 10, ...}),
#  FreqDist({'construction': 12, 'company': 12, 'services': 12, 'provides': 10, 'products': 9, 'transportation': 9, 'logistics': 9, 'systems': 8, 'management': 8, 'customers': 7, ...}),
#  FreqDist({'services': 21, 'management': 21, 'logistics': 20, 'company': 18, 'construction': 14, 'products': 13, 'service': 13, 'operations': 12, 'provides': 10, 'based': 9, ...}),
#  FreqDist({'services': 24, 'solutions': 20, 'company': 17, 'provides': 16, 'management': 15, 'construction': 15, 'customers': 14, 'home': 13, 'providing': 11, 'remodeling': 11, ...}),
#  FreqDist({'services': 42, 'company': 22, 'construction': 22, 'provides': 21, 'management': 19, 'solutions': 19, 'logistics': 16, 'software': 16, 'service': 13, 'founded': 10, ...}),
#  FreqDist({'services': 23, 'management': 23, 'wind': 15, 'technology': 14, 'construction': 13, 'company': 10, 'solutions': 9, 'business': 9, 'trucks': 7, 'projects': 7, ...}),
#  FreqDist({'services': 25, 'company': 17, 'management': 17, 'business': 14, 'construction': 13, 'software': 12, 'provides': 12, 'products': 11, 'solutions': 9, 'best': 8, ...}),
#  FreqDist({'company': 22, 'management': 20, 'construction': 17, 'software': 17, 'solution': 15, 'logistics': 15, 'service': 13, 'customers': 13, 'services': 13, 'business': 12, ...}),
#  FreqDist({'company': 25, 'management': 23, 'construction': 21, 'services': 19, 'solutions': 17, 'project': 13, 'service': 11, 'logistics': 10, 'industry': 9, 'chain': 9, ...}),
#  FreqDist({'company': 25, 'services': 21, 'construction': 18, 'concrete': 14, 'home': 13, 'building': 11, 'business': 11, 'industry': 11, 'provides': 10, 'products': 10, ...}),
#  FreqDist({'murcia': 38, 'de': 35, 'company': 28, 'construction': 24, 'pintores': 21, 'service': 20, 'project': 17, 'software': 16, 'services': 12, 'industry': 12, ...}),
#  FreqDist({'services': 44, 'construction': 33, 'company': 27, 'logistics': 24, 'service': 17, 'new': 16, 'solutions': 15, 'management': 14, 'provides': 14, 'platform': 13, ...}),
#  FreqDist({'construction': 27, 'products': 23, 'online': 19, 'based': 17, 'company': 16, 'solutions': 16, 'services': 15, 'management': 14, 'platform': 13, 'industry': 13, ...}),
#  FreqDist({'logistics': 28, 'company': 24, 'construction': 23, 'platform': 21, 'service': 20, 'services': 19, 'solutions': 14, 'industry': 13, 'building': 13, 'online': 13, ...}),
#  FreqDist({'services': 28, 'company': 27, 'logistics': 23, 'construction': 22, 'service': 15, 'platform': 15, 'projects': 14, 'also': 14, 'mobile': 14, 'provides': 13, ...}),
#  FreqDist({'company': 44, 'delivery': 37, 'construction': 36, 'logistics': 35, 'platform': 31, 'service': 31, 'management': 28, 'data': 25, 'products': 24, 'mobile': 23, ...}),
#  FreqDist({'construction': 47, 'platform': 40, 'company': 35, 'logistics': 35, 'online': 34, 'project': 29, 'services': 27, 'users': 26, 'service': 26, 'technology': 25, ...}),
#  FreqDist({'construction': 69, 'platform': 48, 'company': 41, 'management': 39, 'users': 36, 'service': 35, 'equipment': 35, 'provides': 33, 'online': 33, 'delivery': 32, ...}),
#  FreqDist({'platform': 43, 'delivery': 39, 'construction': 34, 'logistics': 34, 'company': 28, 'management': 28, 'service': 23, 'online': 21, 'provides': 20, 'companies': 19, ...}),
#  FreqDist({'construction': 36, 'platform': 36, 'management': 31, 'logistics': 25, 'company': 24, 'service': 24, 'industry': 21, 'time': 21, 'delivery': 20, 'solutions': 19, ...}),
#  FreqDist({'delivery': 31, 'platform': 27, 'company': 20, 'homes': 19, 'construction': 18, 'companies': 14, 'time': 14, 'customers': 13, 'market': 12, 'services': 12, ...}),
#  FreqDist({'remodeling': 8, 'home': 6, 'provide': 5, 'services': 5, 'customers': 5, 'car': 5, 'quality': 4, 'service': 4, 'hole': 4, 'roofing': 4, ...})]

# %% [markdown]
# Now, we obtained word occurence counts per year from 1819-2019. Let's plot them to visually inspect them.

# %%
# creating scatter plot for the top used words.

words_1  = [i[0] for i in top_1]
counts_1 = [i[1] for i in top_1]

plt.figure(figsize=(18,10))
plt.scatter(x=sorted_years, y=counts_1, alpha=0.6)
plt.xlim(1815, 2025)
plt.xlabel("Foundation Years")
plt.ylabel("Word Occurences")
plt.title("Yearly Top Most Used Words")

annotations_1 = []
    
for i in range(len(sorted_years)):
    annotations_1.append(plt.annotate(words_1[i], (sorted_years[i], counts_1[i] + 2)))
    
adjust_text(annotations_1, x=sorted_years, y=counts_1, autoalign='y',
        only_move={'points':'y', 'text':'xy'}, force_points=0.15)      
plt.show()

# %%
words_2  = [i[0] for i in top_2]
counts_2 = [i[1] for i in top_2]

# sorted_dates = sorted(data["founding_year"])
plt.figure(figsize=(18,10))
plt.scatter(x=sorted_years, y=counts_2, alpha=0.6)
plt.xlim(1815, 2025)
plt.xlabel("Foundation Years")
plt.ylabel("Word Occurences")
plt.title("Yearly Second Most Used Words")

annotations_2= []

for i in range(len(sorted_years)):
    annotations_2.append(plt.annotate(words_2[i], (sorted_years[i], counts_2[i] + 2)))
    
adjust_text(annotations_2, x=sorted_years, y=counts_2, autoalign='y',
        only_move={'points':'y', 'text':'xy'}, force_points=0.15)        
plt.show()

# %%
words_3  = [i[0] for i in top_3]
counts_3 = [i[1] for i in top_3]

# sorted_dates = sorted(data["founding_year"])
plt.figure(figsize=(18,10))
plt.scatter(x=sorted_years, y=counts_3, alpha=0.6)
plt.xlim(1815, 2025)
plt.xlabel("Foundation Years")
plt.ylabel("Word Occurences")
plt.title("Yearly Third Most Used Words")

annotations_3= []

    
for i in range(len(sorted_years)):
    annotations_3.append(plt.annotate(words_3[i], (sorted_years[i], counts_3[i] + 2)))
    
adjust_text(annotations_3, x=sorted_years, y=counts_3, autoalign='y',
        only_move={'points':'y', 'text':'xy'}, force_points=0.15)        
plt.show()
