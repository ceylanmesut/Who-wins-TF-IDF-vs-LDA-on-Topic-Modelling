# %% [markdown]
# # Visualization of the results obtained with LDA Model

# %%
from gensim.models import LdaModel
from gensim import models, corpora
import utils
import pandas as pd

import pyLDAvis
import pyLDAvis.gensim
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# loading trained LDA model
lda = models.LdaModel.load("model\\lda.model")
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
data = pd.read_csv("data\\co_data.csv")
data.head()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                  name                                        description  \
# 0  Pandora Car Rental  Welcome to Pandora Car Rental, Car Hire and Ai...
# 1        SurplusMatch  SurplusMatch is an online marketplace for cont...
# 2       Gimenez Ganga  Giménez Ganga is a company that has been provi...
# 3                SMC3  Freight shippers, motor carriers, logistics se...
# 4        Much Asphalt  Much Asphalt is southern Africa’s commercial s...
#
#           country founding_date  relevancy
# 0  United Kingdom    05/04/2011          0
# 1  United Kingdom    01/01/2008          2
# 2     Switzerland    01/01/1959          0
# 3   United States    01/01/1935          0
# 4    South Africa    01/01/1965          0

# %%
data_lda = utils.build_tokenized_col(data)
training_set = utils.get_training_data(data_lda)

dictionary = corpora.Dictionary(training_set)
corpus = utils.get_corpus(training_set, dictionary)
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# c:\Users\Admin\Desktop\My Thesis Code and Backup Documents\Who-wins-TF-IDF-vs-LDA-on-Topic-Modelling\utils.py:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["tokenized"][index] = pre_process(data["description"][index])

# %%
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda, corpus, dictionary)
vis
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# C:\Users\Admin\anaconda3\lib\site-packages\pyLDAvis\_prepare.py:243: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   default_term_info = default_term_info.sort_values(
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 0      0.059819  0.054817       1        1  47.164484
# 1     -0.095861  0.009881       2        1  28.399425
# 2      0.036042 -0.064699       3        1  24.436091, topic_info=          Term        Freq       Total Category  logprob  loglift
# 230      mobil  175.000000  175.000000  Default  30.0000  30.0000
# 104       data  146.000000  146.000000  Default  29.0000  29.0000
# 644      manag  228.000000  228.000000  Default  28.0000  28.0000
# 856         de   72.000000   72.000000  Default  27.0000  27.0000
# 133  transport  293.000000  293.000000  Default  26.0000  26.0000
# ..         ...         ...         ...      ...      ...      ...
# 152       oper   47.468813  377.224379   Topic3  -5.9304  -0.6637
# 136        use   41.278895  262.537797   Topic3  -6.0701  -0.4409
# 805       cost   38.931146  194.499257   Topic3  -6.1286  -0.1995
# 280       lead   36.483640  158.433077   Topic3  -6.1936  -0.0594
# 478      allow   36.041748  138.696036   Topic3  -6.2058   0.0615
#
# [264 rows x 6 columns], token_table=      Topic      Freq     Term
# term
# 6102      1  0.986042  aalborg
# 3690      2  0.977516     adam
# 3111      2  0.910622    alert
# 478       1  0.273980    allow
# 478       2  0.461441    allow
# ...     ...       ...      ...
# 429       3  0.185974    world
# 2284      3  0.879147   wrapup
# 909       1  0.648458     year
# 909       2  0.170087     year
# 909       3  0.180718     year
#
# [455 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[1, 2, 3])
